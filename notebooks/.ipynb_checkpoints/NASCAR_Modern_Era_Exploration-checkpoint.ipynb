# %% [markdown]
# # NASCAR Modern Era Data Exploration
# by Ra Cohen and Richard Koerner

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# Load the data set
nascar_df = pd.read_csv('../data/NASCAR_Modern_Era.csv')

# Show the loaded data set
nascar_df.head()
# Out:
# /var/folders/g0/7pgly2hx5fd9nkyd5x740m0w0000gn/T/ipykernel_78183/172615984.py:8: DtypeWarning: Columns (10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   nascar_df = pd.read_csv('../data/NASCAR_Modern_Era.csv')
#    Finish_Place  Starting_Position  Num_Racers Car_Num         Driver Make  \
# 0             1                  5          30      43  Petty,Richard  PLY
# 1             2                  1          30      17  Pearson,David  FOR
# 2             3                  6          30      48   Hylton,James  DOD
# 3             4                  8          30      64   Langley,Elmo  FOR
# 4             5                 12          30       4     Sears,John  FOR
#
#    Points  Laps   Status  Track  ...        Date Laps_Led  Prize_Money  \
# 0    48.0   500  RUNNING  Macon  ...  11/17/1968    362.0       $3,500
# 1    43.0   500  RUNNING  Macon  ...  11/17/1968      8.0       $2,345
# ...

# %%
# Split into 3 additional data sets to incorporate additional information easier

# Drivers will have Name (Driver), DOB, and Hall_of_Fame
# drivers_df 

# Tracks will have Track, Track_Length
# track_df

# Races will have Race_ID, Num_Racers, Track, Race_Length, Date, Total_Purse (new)
# races_df
